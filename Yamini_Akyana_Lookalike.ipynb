# %% [markdown]
# # Lookalike Model

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler

# %%
customers = pd.read_csv('/content/drive/MyDrive/Customers.csv')
products = pd.read_csv('/content/drive/MyDrive/Products.csv')
transactions = pd.read_csv('/content/drive/MyDrive/Transactions.csv')

# %%
customers.sample(5)
# Out:
#     CustomerID       CustomerName         Region  SignupDate
# 184      C0185     Kathleen Logan  North America  2023-10-17
# 11       C0012          Kevin May  South America  2024-08-07
# 89       C0090   Charles Hamilton           Asia  2023-10-17
# 167      C0168  Karen Clements MD  South America  2022-12-13
# 33       C0034       Dalton Perez  North America  2023-09-27

# %%
products.sample(5)
# Out:
#    ProductID           ProductName     Category   Price
# 12      P013  BookWorld Smartwatch  Electronics  114.20
# 0       P001  ActiveWear Biography        Books  169.30
# 42      P043       SoundWave Novel        Books  404.40
# 5       P006        ActiveWear Rug   Home Decor  121.32
# 60      P061   HomeSense Desk Lamp   Home Decor  156.96

# %%
transactions.sample(5)
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 961        T00654      C0054      P098  2024-07-07 12:28:18         4
# 363        T00511      C0081      P030  2024-05-26 05:56:36         3
# 931        T00847      C0004      P024  2024-10-24 16:28:30         1
# 71         T00744      C0004      P053  2024-03-11 09:25:22         4
# 417        T00555      C0088      P039  2024-12-15 04:43:29         1
#
#      TotalValue   Price
# 961     1199.72  299.93
# 363      833.58  277.86
# 931      338.66  338.66
# 71      1099.76  274.94
# 417      430.59  430.59

# %%
# Merging transactions data with product data
merged_data = pd.merge(transactions, products, on='ProductID', how='left')
merged_data.sample(5)
# Out:
#     TransactionID CustomerID ProductID      TransactionDate  Quantity  \
# 663        T00336      C0147      P073  2024-11-16 15:45:25         3
# 898        T00851      C0059      P028  2024-02-13 06:45:11         3
# 185        T00421      C0047      P007  2024-01-04 07:47:38         1
# 630        T00596      C0175      P066  2024-09-30 11:36:49         1
# 847        T00399      C0013      P056  2024-03-28 19:16:21         3
#
#      TotalValue  Price_x           ProductName     Category  Price_y
# 663       80.97    26.99  ComfortLiving Laptop  Electronics    26.99
# 898      706.74   235.58   HomeSense Desk Lamp   Home Decor   235.58
# 185      420.15   420.15    SoundWave Cookbook        Books   420.15
# 630      337.22   337.22    SoundWave Textbook        Books   337.22
# 847       48.24    16.08  SoundWave Smartwatch  Electronics    16.08

# %%
# Aggregating transaction data to calculate features
customer_transactions = merged_data.groupby('CustomerID').agg(
    total_spend=('TotalValue', 'sum'),
    transaction_count=('TransactionID', 'count'),
    avg_purchase_value=('TotalValue', 'mean'),
    avg_quantity=('Quantity', 'mean'),
    most_frequent_category=('Category', lambda x: x.mode()[0])
).reset_index()
customer_transactions.sample(5)
# Out:
#     CustomerID  total_spend  transaction_count  avg_purchase_value  \
# 171      C0172      2201.70                  6          366.950000
# 184      C0186      1761.64                  3          587.213333
# 101      C0102      6132.36                  8          766.545000
# 107      C0108      4848.54                  7          692.648571
# 115      C0116      2758.68                  6          459.780000
#
#      avg_quantity most_frequent_category
# 171      1.666667             Home Decor
# 184      2.333333            Electronics
# 101      2.625000            Electronics
# 107      2.285714               Clothing
# 115      1.833333                  Books

# %%
# Merging with customer profile data
merged_customer_data = pd.merge(customers, customer_transactions, on='CustomerID', how='left')
merged_customer_data.sample(5)
# Out:
#     CustomerID         CustomerName         Region  SignupDate  total_spend  \
# 102      C0103       Jennifer Munoz         Europe  2022-05-15      2462.55
# 45       C0046        Beth Cardenas  North America  2024-10-23      5627.83
# 190      C0191  Samantha Gibson DVM  South America  2024-04-07      2997.97
# 176      C0177          Julia Kelly           Asia  2024-06-01      2509.81
# 38       C0039        Angela Harris  South America  2024-10-13      4239.60
#
#      transaction_count  avg_purchase_value  avg_quantity  \
# 102                5.0          492.510000      1.400000
# 45                 7.0          803.975714      2.714286
# 190                5.0          599.594000      2.200000
# 176                4.0          627.452500      2.250000
# 38                 6.0          706.600000      3.000000
#
#     most_frequent_category
# 102               Clothing
# 45                   Books
# 190                  Books
# 176                  Books
# 38             Electronics

# %%
merged_customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    object
#  1   CustomerName            200 non-null    object
#  2   Region                  200 non-null    object
#  3   SignupDate              200 non-null    object
#  4   total_spend             199 non-null    float64
#  5   transaction_count       199 non-null    float64
#  6   avg_purchase_value      199 non-null    float64
#  7   avg_quantity            199 non-null    float64
#  8   most_frequent_category  199 non-null    object
# dtypes: float64(4), object(5)
# memory usage: 14.2+ KB

# %%
merged_customer_data.isnull().sum()
# Out:
# CustomerID                0
# CustomerName              0
# Region                    0
# SignupDate                0
# total_spend               1
# transaction_count         1
# avg_purchase_value        1
# avg_quantity              1
# most_frequent_category    1
# dtype: int64

# %%
merged_customer_data.fillna(0, inplace=True)
merged_customer_data.isnull().sum()
# Out:
# CustomerID                0
# CustomerName              0
# Region                    0
# SignupDate                0
# total_spend               0
# transaction_count         0
# avg_purchase_value        0
# avg_quantity              0
# most_frequent_category    0
# dtype: int64

# %%
# Feature Scaling
scaler = StandardScaler()
scaled_data = scaler.fit_transform(merged_customer_data[['total_spend', 'transaction_count', 'avg_purchase_value', 'avg_quantity']])
scaled_data
# Out:
# array([[-0.05188436,  0.        , -0.05478053, -0.20138205],
#        [-0.86271433, -0.45129368, -0.9039848 , -0.0309241 ],
#        [-0.393842  , -0.45129368, -0.01157526,  1.67365539],
#        [ 1.03537505,  1.35388105, -0.06116966,  0.60829321],
#        [-0.76949861, -0.90258736, -0.02508596, -0.31502068],
#        [ 0.42264614, -0.45129368,  1.54245503,  0.82136565],
#        [-0.47295849, -0.90258736,  0.72745786,  0.25317248],
#        [ 0.44658328,  2.25646841, -1.06339862, -0.88321384],
#        [-1.38789656, -0.90258736, -1.59442354, -2.58779334],
#        [-0.94162972, -0.45129368, -1.05418528,  0.82136565],
#        [ 0.15220099,  0.        ,  0.25596967,  0.13953385],
#        [ 0.96818364,  0.90258736,  0.2614437 ,  0.33434294],
#        [ 1.38632271,  0.90258736,  0.71621421,  0.09083158],
#        [-1.70197101, -1.80517473, -1.51238002, -0.88321384],
#        [-1.24604561, -1.35388105, -0.43615877, -0.88321384],
#        [ 0.23069786,  0.        ,  0.37549279, -0.88321384],
#        [ 0.70867979,  1.35388105, -0.37207089,  0.18214834],
#        [ 0.72391499,  0.        ,  1.12648898,  1.84411334],
#        [-0.68711005,  0.45129368, -1.32350611, -1.16731043],
#        [-1.37381365, -1.80517473,  0.98596117,  0.82136565],
#        [ 1.07072636,  1.35388105, -0.0275274 , -0.67014141],
#        [ 0.65500602,  0.45129368,  0.37946945, -0.0309241 ],
#        [ 0.92871779,  0.45129368,  0.72677508, -0.31502068],
#        [ 0.09622808,  0.90258736, -0.68690031, -0.88321384],
#        [-1.01106048, -0.45129368, -1.18633356, -0.88321384],
#        [ 0.0538489 , -0.45129368,  0.84051943,  0.82136565],
#        [-0.48213331, -0.45129368, -0.17962103,  0.82136565],
#        [ 1.83148074,  1.35388105,  0.69644843,  0.82136565],
#        [-0.90449562, -0.45129368, -0.98350757, -0.0309241 ],
#        [-0.48934055,  0.        , -0.72087243,  0.13953385],
#        [-0.78518494, -0.45129368, -0.75642232, -0.0309241 ],
#        [-1.50937593, -0.90258736, -1.90270747, -1.45140701],
#        [-1.80307881, -1.80517473, -2.28213808, -0.88321384],
#        [-0.20479074,  0.45129368, -0.71150391,  0.53726907],
#        [-0.46872438, -0.45129368, -0.15409968, -0.0309241 ],
#        [-0.85444177, -0.90258736, -0.24065021,  0.25317248],
#        [ 0.43634314,  0.        ,  0.68861822,  0.48044975],
#        [-0.40934896,  0.        , -0.59907338,  0.13953385],
#        [ 0.42918483,  0.45129368,  0.09293092,  0.82136565],
#        [ 0.28232252, -0.90258736,  2.64417004,  1.38955881],
#        [ 1.46742853,  0.90258736,  0.80442539,  1.30838836],
#        [-0.569343  , -0.90258736,  0.48285836, -0.88321384],
#        [-1.26026441, -0.90258736, -1.27052542, -0.88321384],
#        [-0.11950516, -0.90258736,  1.62443304, -0.31502068],
#        [ 1.39786733,  0.90258736,  0.72877021,  1.30838836],
#        [ 1.18373208,  0.90258736,  0.49587545,  0.33434294],
#        [-0.31494291,  0.90258736, -1.1340923 , -1.1267252 ],
#        [ 0.21793573,  0.        ,  0.35606056, -0.20138205],
#        [-0.61663571,  1.35388105, -1.63331422, -0.67014141],
#        [-0.20716598, -0.90258736,  1.40197205,  0.25317248],
#        [ 1.22272505,  0.90258736,  0.53828444, -0.39619113],
#        [-0.52286016, -0.45129368, -0.25713685, -0.0309241 ],
#        [ 1.01449256,  0.45129368,  0.83561241,  0.82136565],
#        [ 2.49503532,  1.35388105,  1.32792356,  0.82136565],
#        [-0.32193273,  0.        , -0.46596921, -0.20138205],
#        [-0.14514355,  0.        , -0.19678148, -0.20138205],
#        [ 0.59050509,  0.45129368,  0.29762593,  0.25317248],
#        [-1.65974946, -1.80517473, -1.19093713, -2.58779334],
#        [ 1.96938021,  1.35388105,  0.82768117,  0.18214834],
#        [-1.83040759, -1.80517473, -2.49019869, -0.88321384],
#        [-0.71296043, -0.90258736,  0.11839366, -0.88321384],
#        [-0.98403064, -0.90258736, -0.56951399,  0.25317248],
#        [-1.12609356, -1.35388105,  0.02045316, -0.0309241 ],
#        [ 0.32057086,  0.        ,  0.51233775,  0.13953385],
#        [ 2.2902923 ,  2.25646841,  0.34026153,  0.3099918 ],
#        [ 0.18985688, -0.90258736,  2.40951563,  0.82136565],
#        [ 0.34832903,  0.45129368, -0.00966486, -0.31502068],
#        [ 1.35907002,  1.35388105,  0.24687633,  0.39522078],
#        [-0.31051313,  0.        , -0.44858117, -0.88321384],
#        [-0.17636946, -0.45129368,  0.40234246,  0.82136565],
#        [-1.11377713, -0.90258736, -0.89877777, -0.31502068],
#        [-0.24480012,  0.        , -0.34852338,  0.13953385],
#        [-0.75520372, -0.90258736,  0.01119085,  1.38955881],
#        [-0.21456344, -0.90258736,  1.38319914,  0.25317248],
#        [ 1.30392871,  1.80517473, -0.14175567,  1.01076337],
#        [-0.60708042,  0.        , -0.90014884, -0.54229795],
#        [-1.42007365, -0.90258736, -1.67608085, -0.31502068],
#        [-1.33407603, -1.80517473,  1.28849322, -0.88321384],
#        [ 0.43568547, -0.45129368,  1.56727292,  0.82136565],
#        [-1.32755365, -1.80517473,  1.33814969,  0.82136565],
#        [ 0.05027789,  0.45129368, -0.38785406, -0.31502068],
#        [ 2.24094504,  0.90258736,  1.6457065 ,  1.30838836],
#        [-1.52579059, -0.90258736, -1.94436373, -2.01960017],
#        [ 0.5387065 ,  1.80517473, -0.78906915, -0.5044184 ],
#        [-0.46289772, -0.90258736,  0.75298956, -0.31502068],
#        [-0.37791651,  0.        , -0.55121282,  0.13953385],
#        [ 1.71443659,  0.90258736,  1.07307281,  1.064877  ],
#        [-0.7145258 ,  0.        , -1.06375036, -0.88321384],
#        [-0.48578585, -1.35388105,  2.45786172,  1.67365539],
#        [ 0.37404896,  0.90258736, -0.38474068, -0.39619113],
#        [-0.16975468,  0.45129368, -0.66704757,  1.38955881],
#        [-0.23590794, -0.45129368,  0.28902226, -0.0309241 ],
#        [ 1.00282293,  1.80517473, -0.39646578, -0.69381612],
#        [-1.2408875 , -0.45129368, -1.62376569, -0.45706897],
#        [-1.17713121, -1.35388105, -0.17382778, -0.0309241 ],
#        [ 1.42565267,  0.        ,  2.19498864,  1.16228155],
#        [-1.80041551, -1.80517473, -2.26186168, -2.58779334],
#        [-0.15868837,  1.35388105, -1.19750627, -1.30935872],
#        [ 1.77503496,  1.35388105,  0.6427315 ,  0.18214834],
#        [ 0.84436165,  0.45129368,  0.6197378 , -0.31502068],
#        [ 1.14196709,  1.35388105,  0.0402692 , -0.0309241 ],
#        [ 1.45796021,  1.35388105,  0.34098568,  0.18214834],
#        [-0.53669848,  0.        , -0.7929819 , -1.90596154],
#        [ 1.70077764,  1.35388105,  0.57206414,  0.18214834],
#        [ 0.7378294 ,  0.45129368,  0.48456185,  0.25317248],
#        [-0.27756966,  0.        , -0.39841986,  0.13953385],
#        [ 0.09454313,  0.        ,  0.16817703, -0.20138205],
#        [ 0.76016313,  0.90258736,  0.03519936, -0.39619113],
#        [ 1.10732237,  2.70776209, -0.76678435,  0.66640388],
#        [-1.36299193, -1.80517473,  1.06834953,  2.52594514],
#        [-0.80277363,  0.        , -1.19812077,  1.16228155],
#        [-0.81011675, -0.90258736, -0.12816451,  0.25317248],
#        [ 0.74035682,  1.35388105, -0.34192528,  0.39522078],
#        [ 1.26667504,  0.        ,  1.95292162,  1.84411334],
#        [-0.17001557, -0.90258736,  1.49625037,  0.25317248],
#        [-0.37574238,  0.45129368, -0.92841992, -1.16731043],
#        [ 0.31432024, -0.45129368,  1.33627722,  0.82136565],
#        [-0.00826592,  0.45129368, -0.46213876, -1.45140701],
#        [-1.22749487,  0.        , -1.84482181, -2.24687744],
#        [-0.53263829, -0.90258736,  0.57600562,  0.82136565],
#        [-1.3454902 , -0.45129368, -1.8228571 , -0.88321384],
#        [ 0.8819197 ,  0.90258736,  0.16762253, -0.15267978],
#        [-1.11419565, -1.35388105,  0.065744  , -0.88321384],
#        [ 0.44262637,  0.90258736, -0.31015548,  0.33434294],
#        [-0.25873084, -0.45129368,  0.24558319, -0.0309241 ],
#        [ 0.60635991,  0.45129368,  0.3177437 , -0.59911726],
#        [-0.11799957,  0.45129368, -0.60137689, -1.16731043],
#        [-1.45491947, -1.35388105, -1.23126232, -1.73550359],
#        [-0.60352028, -0.90258736,  0.39612506,  0.82136565],
#        [-1.54831456, -1.80517473, -0.34255633, -0.88321384],
#        [-0.81864476, -0.90258736, -0.14980646, -0.31502068],
#        [-0.86895407, -0.90258736, -0.27747876,  0.25317248],
#        [-0.30744761, -0.45129368,  0.15286007,  0.39522078],
#        [-0.41889882,  0.        , -0.61361445,  1.16228155],
#        [-0.17088522, -0.45129368,  0.41278066, -0.0309241 ],
#        [ 0.46146519,  0.45129368,  0.13389061,  1.67365539],
#        [-0.06382575,  0.        , -0.07296307, -0.54229795],
#        [ 1.17417679,  0.        ,  1.81207932,  1.50319745],
#        [ 0.13787349,  1.35388105, -0.91528165, -1.52243115],
#        [-0.84890862, -1.35388105,  1.0755911 , -0.0309241 ],
#        [ 3.92641562,  2.25646841,  1.58588168,  0.3099918 ],
#        [-0.65818328, -0.45129368, -0.51469876,  0.39522078],
#        [ 1.41027616,  0.90258736,  0.74226613,  0.82136565],
#        [-1.16603772, -1.35388105, -0.13159909,  2.52594514],
#        [ 1.26169629,  1.35388105,  0.15421011, -0.0309241 ],
#        [-0.47786115, -0.45129368, -0.17148979, -0.88321384],
#        [-0.27260178,  1.80517473, -1.47536756, -1.64080473],
#        [ 1.09130992,  0.        ,  1.68590223,  1.84411334],
#        [ 0.51896542,  0.        ,  0.81442289,  0.82136565],
#        [-1.5597396 , -1.80517473, -0.42953791, -0.88321384],
#        [-1.75344348, -1.80517473, -1.90425233,  2.52594514],
#        [-0.03485007,  0.        , -0.0288433 , -0.88321384],
#        [ 0.70377169,  0.45129368,  0.44134693,  0.53726907],
#        [ 0.13785718,  0.45129368, -0.27672702, -1.16731043],
#        [ 1.04784911,  0.90258736,  0.34808833, -0.15267978],
#        [ 2.27439399,  2.70776209,  0.04096091,  0.04655679],
#        [-0.85545274,  0.        , -1.27833252, -0.88321384],
#        [ 0.14487418, -0.45129368,  1.01376879, -0.45706897],
#        [-0.748752  , -0.90258736,  0.0275637 ,  0.25317248],
#        [-0.28429315,  0.        , -0.40865737,  0.48044975],
#        [-0.16748815,  1.35388105, -1.20588063, -1.30935872],
#        [ 0.7349976 ,  1.35388105, -0.34702541, -0.0309241 ],
#        [ 1.26387585,  0.45129368,  1.15204827,  1.10546223],
#        [-0.19691496,  0.        , -0.27561113, -0.88321384],
#        [ 1.77089325,  1.80517473,  0.25325695,  1.38955881],
#        [-0.5677885 , -0.45129368, -0.34264943,  0.39522078],
#        [-0.6248213 , -0.90258736,  0.34206847,  0.25317248],
#        [ 0.87174478, -0.45129368,  2.3972291 ,  0.82136565],
#        [ 0.58883101,  0.45129368,  0.29550174,  1.38955881],
#        [ 0.80538498,  0.        ,  1.25053912,  0.82136565],
#        [ 0.92148882,  0.        ,  1.42732443,  0.82136565],
#        [-0.67847876,  0.45129368, -1.3125541 , -1.45140701],
#        [ 1.28168195,  1.35388105,  0.17322957, -0.0309241 ],
#        [-0.30330589,  0.        , -0.43760709, -0.20138205],
#        [ 1.5004481 ,  2.25646841, -0.26106592,  0.13953385],
#        [-0.60802616, -0.90258736,  0.38469027,  2.52594514],
#        [-0.51101116, -0.45129368, -0.23458454, -0.45706897],
#        [-0.40283745, -0.45129368, -0.0286964 , -0.45706897],
#        [ 0.11025664,  0.45129368, -0.31174863, -0.31502068],
#        [-1.87517288, -2.25646841, -2.8310076 , -4.29237283],
#        [-0.0556456 ,  0.45129368, -0.52225758, -0.0309241 ],
#        [ 0.83203434,  0.        ,  1.29111673,  1.50319745],
#        [ 0.21754439,  0.        ,  0.35546468, -0.20138205],
#        [-0.03087141,  0.90258736, -0.82513446, -1.61374791],
#        [-0.01394583, -0.90258736,  1.8923159 ,  0.82136565],
#        [-0.9176654 , -0.90258736, -0.40109579, -0.31502068],
#        [ 0.63183525,  0.        ,  0.98628394, -0.54229795],
#        [ 1.99005617,  1.35388105,  0.84735754,  0.18214834],
#        [-0.43850401,  0.        , -0.64346626, -0.54229795],
#        [-0.25380645,  0.        , -0.36223684,  0.48044975],
#        [-0.24568064,  0.        , -0.3498641 , -0.54229795],
#        [-0.74858351, -0.45129368, -0.68675843, -0.88321384],
#        [-0.23952786, -0.45129368,  0.28213242,  0.39522078],
#        [ 0.22784432,  0.90258736, -0.54375371, -0.88321384],
#        [ 0.31866849,  0.45129368, -0.04730033,  0.53726907],
#        [ 0.8331812 , -0.45129368,  2.32383063,  0.82136565],
#        [-0.82689014, -0.90258736, -0.17073115,  0.82136565],
#        [-1.36869358, -1.35388105, -0.90303305, -1.73550359],
#        [-0.79937112, -0.45129368, -0.78342303, -0.45706897],
#        [ 0.71127787,  0.        ,  1.1072471 ,  1.16228155]])

# %%
# Cosine Similarity for customer transaction features
cosine_sim = cosine_similarity(scaled_data)
cosine_sim
# Out:
# array([[ 1.        ,  0.35168776, -0.82653884, ...,  0.7962151 ,
#          0.63576233, -0.87826533],
#        [ 0.35168776,  1.        ,  0.21255862, ...,  0.72972863,
#          0.94207837, -0.70735565],
#        [-0.82653884,  0.21255862,  1.        , ..., -0.35746082,
#         -0.10349378,  0.52938606],
#        ...,
#        [ 0.7962151 ,  0.72972863, -0.35746082, ...,  1.        ,
#          0.90506635, -0.82804335],
#        [ 0.63576233,  0.94207837, -0.10349378, ...,  0.90506635,
#          1.        , -0.86823868],
#        [-0.87826533, -0.70735565,  0.52938606, ..., -0.82804335,
#         -0.86823868,  1.        ]])

# %%
similarity_df = pd.DataFrame(cosine_sim, columns=merged_customer_data['CustomerID'], index=merged_customer_data['CustomerID'])
similarity_df.sample(5)
# Out:
# CustomerID     C0001     C0002     C0003     C0004     C0005     C0006  \
# CustomerID
# C0003      -0.826539  0.212559  1.000000  0.000003  0.084073  0.423054
# C0038       0.163357  0.906791  0.305825 -0.225958  0.315422 -0.717313
# C0099      -0.327238 -0.881244 -0.244467  0.886918 -0.930464  0.296378
# C0098       0.701416  0.218230 -0.685356  0.233357 -0.239348 -0.868106
# C0111      -0.318271  0.706756  0.691021 -0.015169  0.123879 -0.359018
#
# CustomerID     C0007     C0008     C0009     C0010  ...     C0191     C0192  \
# CustomerID                                          ...
# C0003       0.444316 -0.557605 -0.545881  0.650588  ... -0.657256 -0.385029
# C0038      -0.219188  0.166934  0.454464  0.903046  ...  0.459594  0.566825
# C0099      -0.520010  0.480261 -0.642462 -0.711127  ... -0.472142 -0.768357
# C0098      -0.822060  0.901612  0.554703 -0.072373  ...  0.755935  0.467966
# C0111      -0.083536 -0.022324  0.002610  0.946606  ... -0.010865  0.151047
#
# CustomerID     C0193     C0194     C0195     C0196     C0197     C0198  \
# CustomerID
# C0003       0.763125 -0.794755  0.415726  0.260609  0.799718 -0.357461
# C0038      -0.030378  0.106088 -0.047580 -0.829607  0.506514  0.423612
# C0099      -0.476614  0.343660  0.691502  0.408103 -0.766296 -0.806601
# C0098      -0.905626  0.959926 -0.050016 -0.778798 -0.590815  0.282988
# C0111       0.240210 -0.216147  0.297401 -0.510818  0.663228  0.032170
#
# CustomerID     C0199     C0200
# CustomerID
# C0003      -0.103494  0.529386
# C0038       0.768517 -0.610735
# C0099      -0.870167  0.534267
# C0098       0.364494 -0.753601
# C0111       0.438905 -0.168107
#
# [5 rows x 200 columns]

# %%
# Function to get the top N lookalikes based on similarity scores
def get_lookalikes(customer_id, top_n=3):
    sorted_similarities = similarity_df[customer_id].sort_values(ascending=False)
    lookalikes = sorted_similarities.drop(customer_id).head(top_n)
    return lookalikes

# %%
lookalike_data = []
for customer_id in merged_customer_data['CustomerID'][:20]:
    lookalikes = get_lookalikes(customer_id)
    lookalike_data.append({
        'CustomerID': customer_id,
        'Lookalikes': ', '.join(lookalikes.index),  # Mapping CustomerID to lookalikes
        'Scores': ', '.join([str(round(x, 4)) for x in lookalikes.values])  # Similarity scores
    })
lookalike_data
# Out:
# [{'CustomerID': 'C0001',
#   'Lookalikes': 'C0164, C0103, C0137',
#   'Scores': '0.9988, 0.9922, 0.9835'},
#  {'CustomerID': 'C0002',
#   'Lookalikes': 'C0029, C0031, C0077',
#   'Scores': '0.9996, 0.9982, 0.9917'},
#  {'CustomerID': 'C0003',
#   'Lookalikes': 'C0176, C0144, C0073',
#   'Scores': '0.9864, 0.9626, 0.9361'},
#  {'CustomerID': 'C0004',
#   'Lookalikes': 'C0075, C0165, C0113',
#   'Scores': '0.9959, 0.9738, 0.9698'},
#  {'CustomerID': 'C0005',
#   'Lookalikes': 'C0131, C0130, C0150',
#   'Scores': '0.9947, 0.989, 0.9848'},
#  {'CustomerID': 'C0006',
#   'Lookalikes': 'C0079, C0117, C0040',
#   'Scores': '1.0, 0.9971, 0.9894'},
#  {'CustomerID': 'C0007',
#   'Lookalikes': 'C0080, C0140, C0092',
#   'Scores': '0.9839, 0.9745, 0.9631'},
#  {'CustomerID': 'C0008',
#   'Lookalikes': 'C0084, C0090, C0179',
#   'Scores': '0.9916, 0.9837, 0.9734'},
#  {'CustomerID': 'C0009',
#   'Lookalikes': 'C0180, C0192, C0083',
#   'Scores': '0.9888, 0.9822, 0.9807'},
#  {'CustomerID': 'C0010',
#   'Lookalikes': 'C0142, C0151, C0111',
#   'Scores': '0.9692, 0.9551, 0.9466'},
#  {'CustomerID': 'C0011',
#   'Lookalikes': 'C0171, C0096, C0170',
#   'Scores': '0.9994, 0.9991, 0.9973'},
#  {'CustomerID': 'C0012',
#   'Lookalikes': 'C0068, C0102, C0046',
#   'Scores': '0.9965, 0.988, 0.9875'},
#  {'CustomerID': 'C0013',
#   'Lookalikes': 'C0188, C0059, C0141',
#   'Scores': '0.9972, 0.9967, 0.996'},
#  {'CustomerID': 'C0014',
#   'Lookalikes': 'C0071, C0033, C0060',
#   'Scores': '0.9877, 0.9835, 0.9754'},
#  {'CustomerID': 'C0015',
#   'Lookalikes': 'C0150, C0130, C0177',
#   'Scores': '0.9945, 0.9925, 0.9843'},
#  {'CustomerID': 'C0016',
#   'Lookalikes': 'C0107, C0152, C0137',
#   'Scores': '0.9548, 0.872, 0.8034'},
#  {'CustomerID': 'C0017',
#   'Lookalikes': 'C0113, C0109, C0162',
#   'Scores': '0.9912, 0.9907, 0.9907'},
#  {'CustomerID': 'C0018',
#   'Lookalikes': 'C0182, C0148, C0200',
#   'Scores': '0.9859, 0.9801, 0.976'},
#  {'CustomerID': 'C0019',
#   'Lookalikes': 'C0172, C0116, C0088',
#   'Scores': '0.9938, 0.9784, 0.967'},
#  {'CustomerID': 'C0020',
#   'Lookalikes': 'C0080, C0167, C0007',
#   'Scores': '0.9923, 0.9884, 0.9625'}]

# %%
lookalike_df = pd.DataFrame(lookalike_data)
lookalike_df
# Out:
#    CustomerID           Lookalikes                  Scores
# 0       C0001  C0164, C0103, C0137  0.9988, 0.9922, 0.9835
# 1       C0002  C0029, C0031, C0077  0.9996, 0.9982, 0.9917
# 2       C0003  C0176, C0144, C0073  0.9864, 0.9626, 0.9361
# 3       C0004  C0075, C0165, C0113  0.9959, 0.9738, 0.9698
# 4       C0005  C0131, C0130, C0150   0.9947, 0.989, 0.9848
# 5       C0006  C0079, C0117, C0040     1.0, 0.9971, 0.9894
# 6       C0007  C0080, C0140, C0092  0.9839, 0.9745, 0.9631
# 7       C0008  C0084, C0090, C0179  0.9916, 0.9837, 0.9734
# 8       C0009  C0180, C0192, C0083  0.9888, 0.9822, 0.9807
# 9       C0010  C0142, C0151, C0111  0.9692, 0.9551, 0.9466
# 10      C0011  C0171, C0096, C0170  0.9994, 0.9991, 0.9973
# 11      C0012  C0068, C0102, C0046   0.9965, 0.988, 0.9875
# 12      C0013  C0188, C0059, C0141   0.9972, 0.9967, 0.996
# 13      C0014  C0071, C0033, C0060  0.9877, 0.9835, 0.9754
# 14      C0015  C0150, C0130, C0177  0.9945, 0.9925, 0.9843
# 15      C0016  C0107, C0152, C0137   0.9548, 0.872, 0.8034
# 16      C0017  C0113, C0109, C0162  0.9912, 0.9907, 0.9907
# 17      C0018  C0182, C0148, C0200   0.9859, 0.9801, 0.976
# 18      C0019  C0172, C0116, C0088   0.9938, 0.9784, 0.967
# 19      C0020  C0080, C0167, C0007  0.9923, 0.9884, 0.9625

# %%
lookalike_df.to_csv('Lookalike.csv', index=False)

# %%
# Function to take user input and return lookalikes for that customer
def get_user_lookalikes(user_customer_id, top_n=3):
    if user_customer_id not in merged_customer_data['CustomerID'].values:
        return "CustomerID not found!"
    lookalikes = get_lookalikes(user_customer_id, top_n)
    return lookalikes

# %%
user_customer_id = 'C0001'  # Replace with the desired customer ID
lookalikes = get_user_lookalikes(user_customer_id)
print(f"Top 3 lookalikes for {user_customer_id}:")
print(lookalikes)
# Out:
# Top 3 lookalikes for C0001:
# CustomerID
# C0164    0.998778
# C0103    0.992178
# C0137    0.983510
# Name: C0001, dtype: float64
